# %% [markdown]
# # Spot-It
#
# https://stackoverflow.com/questions/6240113/what-are-the-mathematical-computational-principles-behind-this-game
#
# https://stackoverflow.com/questions/27492822/python-spot-it-cards

# %%
from itertools import combinations

# %%
def create_cards(p):
    for min_factor in range(2, 1 + int(p ** 0.5)):
        if p % min_factor == 0:
            break
    else:
        min_factor = p
    cards = []
    for i in range(p):
        cards.append(set([i * p + j for j in range(p)] + [p * p]))
    for i in range(min_factor):
        for j in range(p):
            cards.append(set([k * p + (j + i * k) % p
                              for k in range(p)] + [p * p + 1 + i]))

    cards.append(set([p * p + i for i in range(min_factor + 1)]))
    return cards, p * p + p + 1

def display_using_stars(cards, num_pictures):
    for pictures_for_card in cards:
        print("".join('*' if picture in pictures_for_card else ' '
                      for picture in range(num_pictures)))

def check_cards(cards):
    for card, other_card in combinations(cards, 2):
        if len(card & other_card) != 1:
            print("Cards", sorted(card), "and", sorted(other_card),
                  "have intersection", sorted(card & other_card))

# %%
cards, num_pictures = create_cards(7)
display_using_stars(cards, num_pictures)
check_cards(cards)
# Out:
# *******                                          *
#        *******                                   *
#               *******                            *
#                      *******                     *
#                             *******              *
#                                    *******       *
#                                           ********
# *      *      *      *      *      *      *       *
#  *      *      *      *      *      *      *      *
#   *      *      *      *      *      *      *     *
#    *      *      *      *      *      *      *    *
#     *      *      *      *      *      *      *   *
#      *      *      *      *      *      *      *  *
#       *      *      *      *      *      *      * *
# *       *       *       *       *       *       *  *
#  *       *       *       *       *       **        *
#   *       *       *       *       **       *       *
#    *       *       *       **       *       *      *
#     *       *       **       *       *       *     *
#      *       **       *       *       *       *    *
#       **       *       *       *       *       *   *
# *        *        *        * *        *        *    *
#  *        *        * *        *        *        *   *
#   *        *        * *        *        * *         *
#    *        * *        *        *        * *        *
#     *        * *        *        * *        *       *
#      * *        *        *        * *        *      *
#       * *        *        * *        *        *     *
# *         *         *  *         *  *         *      *
#  *         *  *         *         *  *         *     *
#   *         *  *         *  *         *         *    *
#    *         *  *         *  *         *  *          *
#     *  *         *         *  *         *  *         *
#      *  *         *  *         *         *  *        *
#       *  *         *  *         *  *         *       *
# *          *   *          *   *          *   *        *
#  *          *   *          *   *   *          *       *
#   *          *   *   *          *   *          *      *
#    *   *          *   *          *   *          *     *
#     *   *          *   *          *   *   *           *
#      *   *          *   *   *          *   *          *
#       *   *   *          *   *          *   *         *
# *           *    *    *           *    *    *          *
#  *           *    *    *    *           *    *         *
#   *    *           *    *    *           *    *        *
#    *    *           *    *    *    *           *       *
#     *    *    *           *    *    *           *      *
#      *    *    *           *    *    *    *            *
#       *    *    *    *           *    *    *           *
# *            *     *     *     *     *     *            *
#  *     *            *     *     *     *     *           *
#   *     *     *            *     *     *     *          *
#    *     *     *     *            *     *     *         *
#     *     *     *     *     *            *     *        *
#      *     *     *     *     *     *            *       *
#       *     *     *     *     *     *     *             *
#                                                  ********

# %%
cards
# Out:
# [{0, 1, 2, 3, 4, 5, 6, 49},
#  {7, 8, 9, 10, 11, 12, 13, 49},
#  {14, 15, 16, 17, 18, 19, 20, 49},
#  {21, 22, 23, 24, 25, 26, 27, 49},
#  {28, 29, 30, 31, 32, 33, 34, 49},
#  {35, 36, 37, 38, 39, 40, 41, 49},
#  {42, 43, 44, 45, 46, 47, 48, 49},
#  {0, 7, 14, 21, 28, 35, 42, 50},
#  {1, 8, 15, 22, 29, 36, 43, 50},
#  {2, 9, 16, 23, 30, 37, 44, 50},
#  {3, 10, 17, 24, 31, 38, 45, 50},
#  {4, 11, 18, 25, 32, 39, 46, 50},
#  {5, 12, 19, 26, 33, 40, 47, 50},
#  {6, 13, 20, 27, 34, 41, 48, 50},
#  {0, 8, 16, 24, 32, 40, 48, 51},
#  {1, 9, 17, 25, 33, 41, 42, 51},
#  {2, 10, 18, 26, 34, 35, 43, 51},
#  {3, 11, 19, 27, 28, 36, 44, 51},
#  {4, 12, 20, 21, 29, 37, 45, 51},
#  {5, 13, 14, 22, 30, 38, 46, 51},
#  {6, 7, 15, 23, 31, 39, 47, 51},
#  {0, 9, 18, 27, 29, 38, 47, 52},
#  {1, 10, 19, 21, 30, 39, 48, 52},
#  {2, 11, 20, 22, 31, 40, 42, 52},
#  {3, 12, 14, 23, 32, 41, 43, 52},
#  {4, 13, 15, 24, 33, 35, 44, 52},
#  {5, 7, 16, 25, 34, 36, 45, 52},
#  {6, 8, 17, 26, 28, 37, 46, 52},
#  {0, 10, 20, 23, 33, 36, 46, 53},
#  {1, 11, 14, 24, 34, 37, 47, 53},
#  {2, 12, 15, 25, 28, 38, 48, 53},
#  {3, 13, 16, 26, 29, 39, 42, 53},
#  {4, 7, 17, 27, 30, 40, 43, 53},
#  {5, 8, 18, 21, 31, 41, 44, 53},
#  {6, 9, 19, 22, 32, 35, 45, 53},
#  {0, 11, 15, 26, 30, 41, 45, 54},
#  {1, 12, 16, 27, 31, 35, 46, 54},
#  {2, 13, 17, 21, 32, 36, 47, 54},
#  {3, 7, 18, 22, 33, 37, 48, 54},
#  {4, 8, 19, 23, 34, 38, 42, 54},
#  {5, 9, 20, 24, 28, 39, 43, 54},
#  {6, 10, 14, 25, 29, 40, 44, 54},
#  {0, 12, 17, 22, 34, 39, 44, 55},
#  {1, 13, 18, 23, 28, 40, 45, 55},
#  {2, 7, 19, 24, 29, 41, 46, 55},
#  {3, 8, 20, 25, 30, 35, 47, 55},
#  {4, 9, 14, 26, 31, 36, 48, 55},
#  {5, 10, 15, 27, 32, 37, 42, 55},
#  {6, 11, 16, 21, 33, 38, 43, 55},
#  {0, 13, 19, 25, 31, 37, 43, 56},
#  {1, 7, 20, 26, 32, 38, 44, 56},
#  {2, 8, 14, 27, 33, 39, 45, 56},
#  {3, 9, 15, 21, 34, 40, 46, 56},
#  {4, 10, 16, 22, 28, 41, 47, 56},
#  {5, 11, 17, 23, 29, 35, 48, 56},
#  {6, 12, 18, 24, 30, 36, 42, 56},
#  {49, 50, 51, 52, 53, 54, 55, 56}]

# %%
symbols = sorted(
    [
        "pelikan", "palma", "rukavnik", "morskyKon", "mraznicka", "kormidlo",
        "lehatko", "drink", "vedro", "Aloha", "koral", "nanuk", "opalovaciKrem",
        "Splash!", "plutva", "morskaPanna", "meduza", "krab", "stopa", "Wipeout",
        "pistol", "zralociaPlutva", "plachetnica", "raketa", "slnko", "sandala",
        "melon", "harpuna", "stolicka", "zachranneKoleso", "lietajuciTanier", "ryba",
        "hrad", "kalamar", "fotoaparat", "osuska", "naramok", "sarkan", "kotva",
        "fakla", "kamene", "snehoveGule", "motyka", "kosatka", "plavky",
        "odtlacokMusle", "klobuk", "ponorka", "morskyJez", "more", "musla",
        "slnecnik", "potapacskeOkuliare", "slnecneOkuliare", "majak", "vlna", "lopta"
    ],
    key = str.lower
)

print(len(symbols))
# Out:
# 57

# %%
spot_it = [
    [symbols[card] for card in row] for row in cards
]
spot_it
# Out:
# [['Aloha',
#   'drink',
#   'fakla',
#   'fotoaparat',
#   'harpuna',
#   'hrad',
#   'kalamar',
#   'Splash!'],
#  ['kamene',
#   'klobuk',
#   'koral',
#   'kormidlo',
#   'kosatka',
#   'kotva',
#   'krab',
#   'Splash!'],
#  ['lehatko',
#   'lietajuciTanier',
#   'lopta',
#   'majak',
#   'meduza',
#   'melon',
#   'more',
#   'Splash!'],
#  ['Splash!',
#   'morskaPanna',
#   'morskyJez',
#   'morskyKon',
#   'motyka',
#   'mraznicka',
#   'musla',
#   'nanuk'],
#  ['palma',
#   'pelikan',
#   'pistol',
#   'Splash!',
#   'naramok',
#   'odtlacokMusle',
#   'opalovaciKrem',
#   'osuska'],
#  ['plachetnica',
#   'plavky',
#   'plutva',
#   'ponorka',
#   'potapacskeOkuliare',
#   'raketa',
#   'rukavnik',
#   'Splash!'],
#  ['ryba',
#   'sandala',
#   'sarkan',
#   'slnecneOkuliare',
#   'slnecnik',
#   'slnko',
#   'snehoveGule',
#   'Splash!'],
#  ['Aloha',
#   'plachetnica',
#   'kamene',
#   'ryba',
#   'lehatko',
#   'stolicka',
#   'morskaPanna',
#   'naramok'],
#  ['drink',
#   'plavky',
#   'klobuk',
#   'sandala',
#   'lietajuciTanier',
#   'stolicka',
#   'morskyJez',
#   'odtlacokMusle'],
#  ['fakla',
#   'plutva',
#   'koral',
#   'sarkan',
#   'lopta',
#   'stolicka',
#   'morskyKon',
#   'opalovaciKrem'],
#  ['fotoaparat',
#   'ponorka',
#   'kormidlo',
#   'slnecneOkuliare',
#   'majak',
#   'stolicka',
#   'motyka',
#   'osuska'],
#  ['palma',
#   'harpuna',
#   'potapacskeOkuliare',
#   'kosatka',
#   'slnecnik',
#   'meduza',
#   'stolicka',
#   'mraznicka'],
#  ['pelikan', 'hrad', 'raketa', 'kotva', 'slnko', 'stolicka', 'melon', 'musla'],
#  ['pistol',
#   'kalamar',
#   'rukavnik',
#   'krab',
#   'snehoveGule',
#   'stolicka',
#   'more',
#   'nanuk'],
#  ['Aloha',
#   'palma',
#   'klobuk',
#   'raketa',
#   'lopta',
#   'snehoveGule',
#   'stopa',
#   'motyka'],
#  ['drink',
#   'pelikan',
#   'koral',
#   'rukavnik',
#   'ryba',
#   'majak',
#   'stopa',
#   'mraznicka'],
#  ['fakla',
#   'pistol',
#   'plachetnica',
#   'kormidlo',
#   'sandala',
#   'meduza',
#   'stopa',
#   'musla'],
#  ['fotoaparat',
#   'plavky',
#   'kosatka',
#   'sarkan',
#   'melon',
#   'stopa',
#   'nanuk',
#   'naramok'],
#  ['harpuna',
#   'plutva',
#   'kotva',
#   'slnecneOkuliare',
#   'stopa',
#   'more',
#   'morskaPanna',
#   'odtlacokMusle'],
#  ['hrad',
#   'ponorka',
#   'krab',
#   'lehatko',
#   'slnecnik',
#   'stopa',
#   'morskyJez',
#   'opalovaciKrem'],
#  ['kalamar',
#   'kamene',
#   'potapacskeOkuliare',
#   'lietajuciTanier',
#   'slnko',
#   'stopa',
#   'morskyKon',
#   'osuska'],
#  ['Aloha',
#   'ponorka',
#   'koral',
#   'slnko',
#   'meduza',
#   'vedro',
#   'nanuk',
#   'odtlacokMusle'],
#  ['drink',
#   'potapacskeOkuliare',
#   'kormidlo',
#   'snehoveGule',
#   'melon',
#   'vedro',
#   'morskaPanna',
#   'opalovaciKrem'],
#  ['fakla',
#   'raketa',
#   'ryba',
#   'kosatka',
#   'more',
#   'vedro',
#   'morskyJez',
#   'osuska'],
#  ['palma',
#   'fotoaparat',
#   'rukavnik',
#   'sandala',
#   'kotva',
#   'lehatko',
#   'vedro',
#   'morskyKon'],
#  ['pelikan',
#   'plachetnica',
#   'harpuna',
#   'sarkan',
#   'krab',
#   'lietajuciTanier',
#   'vedro',
#   'motyka'],
#  ['pistol',
#   'plavky',
#   'hrad',
#   'kamene',
#   'slnecneOkuliare',
#   'lopta',
#   'vedro',
#   'mraznicka'],
#  ['plutva',
#   'kalamar',
#   'klobuk',
#   'slnecnik',
#   'majak',
#   'vedro',
#   'musla',
#   'naramok'],
#  ['Aloha',
#   'pelikan',
#   'plavky',
#   'kormidlo',
#   'slnecnik',
#   'more',
#   'vlna',
#   'morskyKon'],
#  ['drink',
#   'pistol',
#   'plutva',
#   'kosatka',
#   'lehatko',
#   'slnko',
#   'vlna',
#   'motyka'],
#  ['fakla',
#   'ponorka',
#   'kotva',
#   'lietajuciTanier',
#   'snehoveGule',
#   'vlna',
#   'mraznicka',
#   'naramok'],
#  ['fotoaparat',
#   'potapacskeOkuliare',
#   'ryba',
#   'krab',
#   'lopta',
#   'vlna',
#   'musla',
#   'odtlacokMusle'],
#  ['harpuna',
#   'kamene',
#   'raketa',
#   'sandala',
#   'majak',
#   'vlna',
#   'nanuk',
#   'opalovaciKrem'],
#  ['hrad',
#   'klobuk',
#   'rukavnik',
#   'sarkan',
#   'meduza',
#   'morskaPanna',
#   'vlna',
#   'osuska'],
#  ['palma',
#   'plachetnica',
#   'kalamar',
#   'koral',
#   'slnecneOkuliare',
#   'melon',
#   'vlna',
#   'morskyJez'],
#  ['Aloha',
#   'rukavnik',
#   'kosatka',
#   'slnecneOkuliare',
#   'lietajuciTanier',
#   'Wipeout',
#   'musla',
#   'opalovaciKrem'],
#  ['drink',
#   'plachetnica',
#   'kotva',
#   'slnecnik',
#   'lopta',
#   'Wipeout',
#   'nanuk',
#   'osuska'],
#  ['palma',
#   'fakla',
#   'plavky',
#   'krab',
#   'slnko',
#   'majak',
#   'morskaPanna',
#   'Wipeout'],
#  ['pelikan',
#   'fotoaparat',
#   'plutva',
#   'kamene',
#   'snehoveGule',
#   'meduza',
#   'morskyJez',
#   'Wipeout'],
#  ['pistol',
#   'harpuna',
#   'ponorka',
#   'klobuk',
#   'ryba',
#   'melon',
#   'Wipeout',
#   'morskyKon'],
#  ['hrad',
#   'potapacskeOkuliare',
#   'koral',
#   'sandala',
#   'more',
#   'Wipeout',
#   'motyka',
#   'naramok'],
#  ['kalamar',
#   'raketa',
#   'kormidlo',
#   'sarkan',
#   'lehatko',
#   'Wipeout',
#   'mraznicka',
#   'odtlacokMusle'],
#  ['Aloha',
#   'pistol',
#   'potapacskeOkuliare',
#   'kotva',
#   'sarkan',
#   'majak',
#   'morskyJez',
#   'zachranneKoleso'],
#  ['drink',
#   'raketa',
#   'krab',
#   'slnecneOkuliare',
#   'meduza',
#   'zachranneKoleso',
#   'morskyKon',
#   'naramok'],
#  ['fakla',
#   'kamene',
#   'rukavnik',
#   'slnecnik',
#   'melon',
#   'zachranneKoleso',
#   'motyka',
#   'odtlacokMusle'],
#  ['fotoaparat',
#   'plachetnica',
#   'klobuk',
#   'slnko',
#   'more',
#   'zachranneKoleso',
#   'mraznicka',
#   'opalovaciKrem'],
#  ['harpuna',
#   'plavky',
#   'koral',
#   'lehatko',
#   'snehoveGule',
#   'zachranneKoleso',
#   'musla',
#   'osuska'],
#  ['palma',
#   'hrad',
#   'plutva',
#   'kormidlo',
#   'ryba',
#   'lietajuciTanier',
#   'zachranneKoleso',
#   'nanuk'],
#  ['pelikan',
#   'kalamar',
#   'ponorka',
#   'kosatka',
#   'sandala',
#   'lopta',
#   'morskaPanna',
#   'zachranneKoleso'],
#  ['Aloha',
#   'plutva',
#   'sandala',
#   'krab',
#   'melon',
#   'zralociaPlutva',
#   'mraznicka',
#   'osuska'],
#  ['palma',
#   'drink',
#   'ponorka',
#   'kamene',
#   'sarkan',
#   'more',
#   'zralociaPlutva',
#   'musla'],
#  ['pelikan',
#   'fakla',
#   'potapacskeOkuliare',
#   'klobuk',
#   'slnecneOkuliare',
#   'lehatko',
#   'zralociaPlutva',
#   'nanuk'],
#  ['pistol',
#   'fotoaparat',
#   'raketa',
#   'koral',
#   'slnecnik',
#   'lietajuciTanier',
#   'morskaPanna',
#   'zralociaPlutva'],
#  ['harpuna',
#   'rukavnik',
#   'kormidlo',
#   'slnko',
#   'lopta',
#   'morskyJez',
#   'zralociaPlutva',
#   'naramok'],
#  ['plachetnica',
#   'hrad',
#   'kosatka',
#   'snehoveGule',
#   'majak',
#   'morskyKon',
#   'zralociaPlutva',
#   'odtlacokMusle'],
#  ['plavky',
#   'kalamar',
#   'ryba',
#   'kotva',
#   'meduza',
#   'motyka',
#   'zralociaPlutva',
#   'opalovaciKrem'],
#  ['Splash!',
#   'stolicka',
#   'stopa',
#   'vedro',
#   'vlna',
#   'Wipeout',
#   'zachranneKoleso',
#   'zralociaPlutva']]
